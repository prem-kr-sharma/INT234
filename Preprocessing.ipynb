# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Collected_data - Form Responses 1.csv')
df.head()
# df.['']
# Out:
#             Timestamp      Minor Chosen  Proficiency in python  \
# 0  12/7/2025 18:30:40      Data Science                    4.0
# 1  12/7/2025 18:34:50  Machine learning                    1.0
# 2  12/7/2025 18:37:28     Cybersecurity                    4.0
# 3  12/7/2025 18:37:37      Data Science                    4.0
# 4  12/7/2025 18:38:47      Data Science                    4.0
#
#    Proficiency in DBMS, SQL  Proficiency in Html, CSS, Javascript  \
# 0                       4.0                                   4.0
# 1                       3.0                                   2.0
# 2                       4.0                                   4.0
# 3                       4.0                                   4.0
# 4                       3.0                                   1.0
#
#    Proficiency in Backend Development  \
# 0                                 4.0
# 1                                 5.0
# 2                                 3.0
# ...

# %%
df_synthetic = pd.read_csv('DataGenerated.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 20 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Timestamp                                               83 non-null     object
#  1   Minor Chosen                                            83 non-null     object
#  2   Proficiency in python                                   82 non-null     float64
#  3   Proficiency in DBMS, SQL                                82 non-null     float64
#  4   Proficiency in Html, CSS, Javascript                    72 non-null     float64
#  5   Proficiency in Backend Development                      70 non-null     float64
#  6   Proficiency in Probability & Statistics                 81 non-null     float64
#  7   Proficiency in Linear Algebra                           82 non-null     float64
# ...

# %%
df_synthetic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Timestamp                                              500 non-null    object
#  1   Minor Chosen                                           500 non-null    object
#  2   Proficiency in python                                  431 non-null    float64
#  3   Proficiency in DBMS, SQL                               419 non-null    float64
#  4   Proficiency in Html, CSS, Javascript                   423 non-null    float64
#  5   Proficiency in Backend Development                     422 non-null    float64
#  6   Proficiency in Probability & Statistics                428 non-null    float64
#  7   Proficiency in Linear Algebra                          438 non-null    float64
# ...

# %%
def clean_columns(df):
    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(' ', '_')
    )
    return df

df1 = clean_columns(df)
df2 = clean_columns(df_synthetic)


df = pd.concat([df, df_synthetic], ignore_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   timestamp                                              583 non-null    object
#  1   minor_chosen                                           583 non-null    object
#  2   proficiency_in_python                                  513 non-null    float64
#  3   proficiency_in_dbms,_sql                               501 non-null    float64
#  4   proficiency_in_html,_css,_javascript                   495 non-null    float64
#  5   proficiency_in_backend_development                     492 non-null    float64
#  6   proficiency_in_probability_&_statistics                509 non-null    float64
#  7   proficiency_in_linear_algebra                          520 non-null    float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   timestamp                                              583 non-null    object
#  1   minor_chosen                                           583 non-null    object
#  2   proficiency_in_python                                  513 non-null    float64
#  3   proficiency_in_dbms,_sql                               501 non-null    float64
#  4   proficiency_in_html,_css,_javascript                   495 non-null    float64
#  5   proficiency_in_backend_development                     492 non-null    float64
#  6   proficiency_in_probability_&_statistics                509 non-null    float64
#  7   proficiency_in_linear_algebra                          520 non-null    float64
# ...

# %%
df.sample(4)
# Out:
#                timestamp     minor_chosen  proficiency_in_python  \
# 233  2025-12-25 10:02:00     Data Science                    3.0
# 177  2025-12-09 15:24:00       Full Stack                    3.0
# 468  2025-12-18 13:56:00  Cloud Computing                    1.0
# 207  2025-12-14 17:43:00       Full Stack                    3.0
#
#      proficiency_in_dbms,_sql  proficiency_in_html,_css,_javascript  \
# 233                       3.0                                   3.0
# 177                       4.0                                   3.0
# 468                       3.0                                   2.0
# 207                       3.0                                   5.0
#
#      proficiency_in_backend_development  \
# 233                                 1.0
# 177                                 5.0
# 468                                 5.0
# 207                                 4.0
#
#      proficiency_in_probability_&_statistics  proficiency_in_linear_algebra  \
# ...

# %% [markdown]
# ##Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   timestamp                                              583 non-null    object
#  1   minor_chosen                                           583 non-null    object
#  2   proficiency_in_python                                  513 non-null    float64
#  3   proficiency_in_dbms,_sql                               501 non-null    float64
#  4   proficiency_in_html,_css,_javascript                   495 non-null    float64
#  5   proficiency_in_backend_development                     492 non-null    float64
#  6   proficiency_in_probability_&_statistics                509 non-null    float64
#  7   proficiency_in_linear_algebra                          520 non-null    float64
# ...

# %%
df = df.drop(columns = ['timestamp'])
df.isnull().sum()
# Out:
# minor_chosen                                               0
# proficiency_in_python                                     70
# proficiency_in_dbms,_sql                                  82
# proficiency_in_html,_css,_javascript                      88
# proficiency_in_backend_development                        91
# proficiency_in_probability_&_statistics                   74
# proficiency_in_linear_algebra                             63
# proficiency_in_data_handling(pandas,_excel)              104
# proficiency_in_machine_learning_algorithms                96
# proficiency_in_cybersecurity_basics                       97
# proficiency_in_networking                                 72
# proficiency_in_cloud_basics                               88
# proficiency_in_iot_basics                                 96
# primary_interest_area_at_a_time_(more_than_one)            0
# career_goal_at_the_time                                    0
# ...

# %%
l = df.select_dtypes(include=['number']).columns
l
# Out:
# Index(['proficiency_in_python', 'proficiency_in_dbms,_sql',
#        'proficiency_in_html,_css,_javascript',
#        'proficiency_in_backend_development',
#        'proficiency_in_probability_&_statistics',
#        'proficiency_in_linear_algebra',
#        'proficiency_in_data_handling(pandas,_excel)',
#        'proficiency_in_machine_learning_algorithms',
#        'proficiency_in_cybersecurity_basics', 'proficiency_in_networking',
#        'proficiency_in_cloud_basics', 'proficiency_in_iot_basics',
#        'satisfaction_with_the_chosen_minor'],
#       dtype='object')

# %%
for i in l:
  df[i].fillna(1, inplace=True)
# Out:
# /tmp/ipython-input-2001170197.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(1, inplace=True)

# %%
df.isnull().sum()
# Out:
# minor_chosen                                             0
# proficiency_in_python                                    0
# proficiency_in_dbms,_sql                                 0
# proficiency_in_html,_css,_javascript                     0
# proficiency_in_backend_development                       0
# proficiency_in_probability_&_statistics                  0
# proficiency_in_linear_algebra                            0
# proficiency_in_data_handling(pandas,_excel)              0
# proficiency_in_machine_learning_algorithms               0
# proficiency_in_cybersecurity_basics                      0
# proficiency_in_networking                                0
# proficiency_in_cloud_basics                              0
# proficiency_in_iot_basics                                0
# primary_interest_area_at_a_time_(more_than_one)          0
# career_goal_at_the_time                                  0
# was_there_any_peer_influence_while_choosing_minor        0
# ...

# %%
df.describe()
# Out:
#        proficiency_in_python  proficiency_in_dbms,_sql  \
# count             583.000000                583.000000
# mean                2.686106                  2.619211
# std                 1.345450                  1.295952
# min                 1.000000                  1.000000
# 25%                 1.000000                  1.000000
# 50%                 3.000000                  3.000000
# 75%                 4.000000                  4.000000
# max                 5.000000                  5.000000
#
#        proficiency_in_html,_css,_javascript  \
# count                            583.000000
# mean                               2.315609
# std                                1.258598
# min                                1.000000
# 25%                                1.000000
# 50%                                2.000000
# 75%                                3.000000
# max                                5.000000
#
#        proficiency_in_backend_development  \
# ...

# %%
df.to_csv('cleaned_data.csv', index=False)
